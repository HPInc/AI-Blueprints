# %% [markdown]
# # Fine-tuning with Dreambooth

# %%
# !pip install "jax[cuda12_local]==0.4.23" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Collecting jax==0.4.23 (from jax[cuda12_local]==0.4.23)
#   Downloading jax-0.4.23-py3-none-any.whl.metadata (24 kB)
# Collecting ml-dtypes>=0.2.0 (from jax==0.4.23->jax[cuda12_local]==0.4.23)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.10/site-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (1.24.3)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.10/site-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.10/site-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (1.12.0)
# Collecting jaxlib==0.4.23+cuda12.cudnn89 (from jax[cuda12_local]==0.4.23)
#   Downloading https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.23%2Bcuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl (131.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading jax-0.4.23-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.2 MB/s eta 0:00:0000:0100:010m
# Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: ml-dtypes, jaxlib, jax
# Successfully installed jax-0.4.23 jaxlib-0.4.23+cuda12.cudnn89 ml-dtypes-0.4.0
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Installing the libraries

# %%
# !pip install torch==2.1.0+cu121 torchvision==0.16.0+cu121 torchaudio==2.1.0 torchtext==0.16.0+cpu torchdata==0.7.0 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.1.0+cu121
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (2200.6 MB)
# Collecting torchvision==0.16.0+cu121
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.16.0%2Bcu121-cp310-cp310-linux_x86_64.whl (7.0 MB)
# Collecting torchaudio==2.1.0
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (3.3 MB)
# Requirement already satisfied: torchtext==0.16.0+cpu in /opt/conda/lib/python3.10/site-packages (0.16.0+cpu)
# Requirement already satisfied: torchdata==0.7.0 in /opt/conda/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (2024.2.0)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.0+cu121) (2.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.0+cu121) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.0+cu121) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.0+cu121) (9.5.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torchtext==0.16.0+cpu) (4.65.0)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.10/site-packages (from torchdata==0.7.0) (2.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.1.0+cu121) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.0+cu121) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.0+cu121) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.0+cu121) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.0+cu121) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1
#     Uninstalling torchvision-0.13.1:
#       Successfully uninstalled torchvision-0.13.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1
#     Uninstalling torchaudio-0.12.1:
#       Successfully uninstalled torchaudio-0.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xformers 0.0.27.post2 requires torch==2.4.0, but you have torch 2.1.0+cu121 which is incompatible.
# Successfully installed torch-2.1.0+cu121 torchaudio-2.1.0+cu121 torchvision-0.16.0+cu121
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes gradio natsort safetensors xformers
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
nvcc --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 nvcc --version
#
# NameError: name 'nvcc' is not defined

# %% [markdown]
# ## Loading the model

# %% [markdown]
# > Terms of use
#
# * https://huggingface.co/spaces/CompVis/stable-diffusion-license

# %%
model_sd = "runwayml/stable-diffusion-v1-5"
output_dir = "/home/jovyan/local/Fine Tuning/Dreambooth/stable_diffusion_weights/zwx"

# %%
# !mkdir -p $output_dir

# %% [markdown]
# ## Training
#
# Three components are needed:
# 1. unique identifier
# 2. class name
# 3. images
#
# Instance prompt
# a photo of [unique identifier] [class name]
#
# Class prompt
# > a photo of [class name]
#
# The instance prompt will be as follows:
# > a photo of zwx person
#
# As the subject is a person, the class prompt will be as follows:
# > a photo of a person

# %%
concepts_list = [
    {
        "instance_prompt": "zwx",
        "class_prompt": "photo of a person",
        "instance_data_dir": "/content/data/zwx",
        "class_data_dir": "/content/data/person"

    }
]

# %%
import json
import os
import random

for c in concepts_list:
  os.makedirs(c["instance_data_dir"], exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 6
#       3 import random
#       5 for c in concepts_list:
# ----> 6   os.makedirs(c["instance_data_dir"], exist_ok=True)
#
# File /opt/conda/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /opt/conda/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /opt/conda/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/content'

# %%
with open("concepts_list.json", "w") as f:
  json.dump(concepts_list, f, indent=4)

# %% [markdown]
# ### Parameters

# %%
num_imgs = 10
num_class_images = num_imgs * 12
max_num_steps = num_imgs * 80
learning_rate = 1e-6 # 0.0000001
lr_warmup_steps = int(max_num_steps / 10)
print(num_imgs, num_class_images, max_num_steps, learning_rate, lr_warmup_steps)
# Out:
# 10 120 800 1e-06 80

# %%
# !python3 train_dreambooth.py \
  --pretrained_model_name_or_path=$model_sd \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$output_dir \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=777 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=$learning_rate \
  --lr_scheduler="constant" \
  --lr_warmup_steps=80 \
  --num_class_images=$num_class_images \
  --sample_batch_size=4 \
  --max_train_steps=$max_num_steps \
  --save_interval=10000 \
  --save_sample_prompt="zwx" \
  --concepts_list="concepts_list.json"
# Out:
# 2024-04-15 20:46:27.351090: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 20:46:27.351146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 20:46:27.458292: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 20:46:29.552334: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# config.json: 100% 547/547 [00:00<00:00, 2.35MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 218MB/s]
# model_index.json: 100% 543/543 [00:00<00:00, 2.69MB/s]
# safety_checker/model.safetensors not found
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# (…)ature_extractor/preprocessor_config.json: 100% 342/342 [00:00<00:00, 1.88MB/s]
# Fetching 15 files:   7% 1/15 [00:00<00:07,  1.99it/s]
# text_encoder/config.json: 100% 636/636 [00:00<00:00, 3.29MB/s]
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# scheduler/scheduler_config.json: 100% 307/307 [00:00<00:00, 2.03MB/s]
#
#
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 2.80MB/s]
#
#
# tokenizer/tokenizer_config.json: 100% 822/822 [00:00<00:00, 3.92MB/s]
#
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 3.95MB/s]
#
# safety_checker/config.json: 100% 4.70k/4.70k [00:00<00:00, 16.8MB/s]
# Fetching 15 files:  20% 3/15 [00:00<00:02,  4.65it/s]
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# unet/config.json: 100% 806/806 [00:00<00:00, 4.53MB/s]
#
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 23.6MB/s]
#
#
# pytorch_model.bin:   2% 10.5M/608M [00:00<00:06, 98.9MB/s]
# vae/config.json: 100% 609/609 [00:00<00:00, 3.18MB/s]
#
# diffusion_pytorch_model.bin:   0% 0.00/1.72G [00:00<?, ?B/s]
#
#
# pytorch_model.bin:   0% 0.00/246M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   1% 10.5M/1.72G [00:00<00:19, 86.6MB/s]
#
# pytorch_model.bin:   7% 41.9M/608M [00:00<00:03, 169MB/s]
# diffusion_pytorch_model.bin:   1% 21.0M/1.72G [00:00<00:18, 91.5MB/s]
#
#
# pytorch_model.bin:   9% 21.0M/246M [00:00<00:01, 122MB/s]
#
# pytorch_model.bin:  10% 62.9M/608M [00:00<00:03, 150MB/s]
#
#
#
# diffusion_pytorch_model.bin:   0% 0.00/167M [00:00<?, ?B/s]
#
#
# pytorch_model.bin:  17% 41.9M/246M [00:00<00:01, 115MB/s]
# diffusion_pytorch_model.bin:   2% 41.9M/1.72G [00:00<00:17, 95.0MB/s]
#
#
#
# diffusion_pytorch_model.bin:   6% 10.5M/167M [00:00<00:02, 57.8MB/s]
#
# pytorch_model.bin:  14% 83.9M/608M [00:00<00:04, 114MB/s]
# diffusion_pytorch_model.bin:   3% 52.4M/1.72G [00:00<00:18, 90.7MB/s]
#
#
#
# diffusion_pytorch_model.bin:  13% 21.0M/167M [00:00<00:02, 58.9MB/s]
# diffusion_pytorch_model.bin:   4% 62.9M/1.72G [00:00<00:21, 77.2MB/s]
#
#
# pytorch_model.bin:  26% 62.9M/246M [00:00<00:02, 85.0MB/s]
#
#
#
# diffusion_pytorch_model.bin:  19% 31.5M/167M [00:00<00:02, 66.9MB/s]
#
#
# pytorch_model.bin:  30% 73.4M/246M [00:00<00:02, 84.3MB/s]
#
# pytorch_model.bin:  17% 105M/608M [00:01<00:05, 85.9MB/s]
#
#
#
# diffusion_pytorch_model.bin:  25% 41.9M/167M [00:00<00:01, 71.4MB/s]
# diffusion_pytorch_model.bin:   5% 83.9M/1.72G [00:00<00:19, 85.6MB/s]
#
#
# pytorch_model.bin:  34% 83.9M/246M [00:00<00:01, 88.4MB/s]
#
#
#
# diffusion_pytorch_model.bin:  31% 52.4M/167M [00:00<00:01, 76.9MB/s]
# diffusion_pytorch_model.bin:   5% 94.4M/1.72G [00:01<00:19, 85.0MB/s]
#
#
# pytorch_model.bin:  38% 94.4M/246M [00:01<00:01, 84.8MB/s]
#
# pytorch_model.bin:  21% 126M/608M [00:01<00:05, 84.2MB/s]
#
#
#
# diffusion_pytorch_model.bin:  38% 62.9M/167M [00:00<00:01, 83.4MB/s]
# diffusion_pytorch_model.bin:   6% 105M/1.72G [00:01<00:18, 86.9MB/s]
#
#
# pytorch_model.bin:  43% 105M/246M [00:01<00:01, 81.4MB/s]
#
# pytorch_model.bin:  22% 136M/608M [00:01<00:05, 84.6MB/s]
# diffusion_pytorch_model.bin:   7% 115M/1.72G [00:01<00:18, 87.2MB/s]
#
#
#
# diffusion_pytorch_model.bin:  44% 73.4M/167M [00:01<00:01, 73.6MB/s]
#
# pytorch_model.bin:  24% 147M/608M [00:01<00:05, 82.4MB/s]
#
#
# pytorch_model.bin:  51% 126M/246M [00:01<00:01, 94.1MB/s]
# diffusion_pytorch_model.bin:   7% 126M/1.72G [00:01<00:19, 81.1MB/s]
#
#
#
# diffusion_pytorch_model.bin:  50% 83.9M/167M [00:01<00:01, 76.5MB/s]
#
# pytorch_model.bin:  26% 157M/608M [00:01<00:05, 83.7MB/s]
#
#
# pytorch_model.bin:  55% 136M/246M [00:01<00:01, 86.6MB/s]
#
#
#
# diffusion_pytorch_model.bin:  56% 94.4M/167M [00:01<00:00, 80.6MB/s]
# diffusion_pytorch_model.bin:   9% 147M/1.72G [00:01<00:16, 97.9MB/s]
#
# pytorch_model.bin:  29% 178M/608M [00:01<00:05, 79.8MB/s]
#
#
# pytorch_model.bin:  64% 157M/246M [00:01<00:01, 87.2MB/s]
#
#
#
# diffusion_pytorch_model.bin:  63% 105M/167M [00:01<00:00, 64.0MB/s]
# diffusion_pytorch_model.bin:   9% 157M/1.72G [00:01<00:20, 76.1MB/s]
#
#
# pytorch_model.bin:  68% 168M/246M [00:01<00:00, 79.3MB/s]
#
# pytorch_model.bin:  31% 189M/608M [00:02<00:05, 72.7MB/s]
# diffusion_pytorch_model.bin:  10% 168M/1.72G [00:02<00:21, 73.3MB/s]
#
#
#
# diffusion_pytorch_model.bin:  69% 115M/167M [00:01<00:00, 58.8MB/s]
#
# pytorch_model.bin:  33% 199M/608M [00:02<00:05, 73.8MB/s]
#
#
# pytorch_model.bin:  72% 178M/246M [00:02<00:00, 76.3MB/s]
# diffusion_pytorch_model.bin:  10% 178M/1.72G [00:02<00:22, 68.5MB/s]
#
#
#
# diffusion_pytorch_model.bin:  75% 126M/167M [00:01<00:00, 58.0MB/s]
#
# pytorch_model.bin:  34% 210M/608M [00:02<00:05, 70.7MB/s]
#
#
# pytorch_model.bin:  77% 189M/246M [00:02<00:00, 72.3MB/s]
# diffusion_pytorch_model.bin:  11% 189M/1.72G [00:02<00:23, 65.8MB/s]
#
#
#
# diffusion_pytorch_model.bin:  81% 136M/167M [00:02<00:00, 57.6MB/s]
#
#
# pytorch_model.bin:  81% 199M/246M [00:02<00:00, 54.1MB/s]
# diffusion_pytorch_model.bin:  12% 199M/1.72G [00:02<00:29, 51.2MB/s]
#
#
# pytorch_model.bin:  85% 210M/246M [00:02<00:00, 59.2MB/s]
#
# pytorch_model.bin:  36% 220M/608M [00:02<00:08, 44.2MB/s]
#
#
#
# diffusion_pytorch_model.bin:  88% 147M/167M [00:02<00:00, 44.5MB/s]
# diffusion_pytorch_model.bin:  12% 210M/1.72G [00:02<00:26, 56.3MB/s]
#
#
# pytorch_model.bin:  89% 220M/246M [00:02<00:00, 64.1MB/s]
#
#
#
# diffusion_pytorch_model.bin:  94% 157M/167M [00:02<00:00, 51.3MB/s]
#
# pytorch_model.bin:  38% 231M/608M [00:03<00:07, 50.0MB/s]
# diffusion_pytorch_model.bin:  13% 220M/1.72G [00:02<00:24, 61.5MB/s]
#
#
#
# diffusion_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 57.7MB/s]
#
#
# pytorch_model.bin:  94% 231M/246M [00:02<00:00, 67.5MB/s]
#
# pytorch_model.bin:  40% 241M/608M [00:03<00:06, 56.6MB/s]
# diffusion_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 60.5MB/s]
#
#
#
# pytorch_model.bin:  98% 241M/246M [00:03<00:00, 72.5MB/s]
#
# pytorch_model.bin:  41% 252M/608M [00:03<00:05, 60.9MB/s]
# pytorch_model.bin: 100% 246M/246M [00:03<00:00, 76.3MB/s]
#
# diffusion_pytorch_model.bin:  15% 252M/1.72G [00:03<00:19, 76.9MB/s]
#
# pytorch_model.bin:  43% 262M/608M [00:03<00:05, 63.8MB/s]
# diffusion_pytorch_model.bin:  16% 273M/1.72G [00:03<00:14, 100MB/s]
#
# pytorch_model.bin:  47% 283M/608M [00:03<00:03, 81.5MB/s]
# diffusion_pytorch_model.bin:  17% 294M/1.72G [00:03<00:12, 110MB/s]
#
# pytorch_model.bin:  50% 304M/608M [00:03<00:03, 93.9MB/s]
# diffusion_pytorch_model.bin:  18% 315M/1.72G [00:03<00:12, 112MB/s]
#
# pytorch_model.bin:  53% 325M/608M [00:03<00:02, 104MB/s]
# diffusion_pytorch_model.bin:  20% 336M/1.72G [00:03<00:12, 114MB/s]
#
# pytorch_model.bin:  57% 346M/608M [00:04<00:02, 109MB/s]
#
# pytorch_model.bin:  60% 367M/608M [00:05<00:06, 36.4MB/s]
# diffusion_pytorch_model.bin:  21% 357M/1.72G [00:05<00:38, 35.6MB/s]
#
# pytorch_model.bin:  64% 388M/608M [00:05<00:04, 48.4MB/s]
# diffusion_pytorch_model.bin:  22% 377M/1.72G [00:05<00:28, 47.9MB/s]
# diffusion_pytorch_model.bin:  23% 398M/1.72G [00:05<00:21, 62.8MB/s]
#
# pytorch_model.bin:  67% 409M/608M [00:05<00:03, 62.3MB/s]
# diffusion_pytorch_model.bin:  24% 419M/1.72G [00:05<00:16, 77.5MB/s]
#
# pytorch_model.bin:  71% 430M/608M [00:05<00:02, 75.0MB/s]
# diffusion_pytorch_model.bin:  26% 440M/1.72G [00:05<00:14, 89.3MB/s]
#
# pytorch_model.bin:  74% 451M/608M [00:06<00:01, 88.1MB/s]
# diffusion_pytorch_model.bin:  27% 461M/1.72G [00:06<00:12, 99.8MB/s]
#
# pytorch_model.bin:  78% 472M/608M [00:06<00:01, 96.0MB/s]
# diffusion_pytorch_model.bin:  28% 482M/1.72G [00:06<00:11, 111MB/s]
#
# pytorch_model.bin:  81% 493M/608M [00:06<00:01, 110MB/s]
# diffusion_pytorch_model.bin:  29% 503M/1.72G [00:06<00:09, 122MB/s]
#
# pytorch_model.bin:  84% 514M/608M [00:06<00:00, 120MB/s]
# diffusion_pytorch_model.bin:  30% 524M/1.72G [00:06<00:08, 136MB/s]
#
# pytorch_model.bin:  88% 535M/608M [00:06<00:00, 132MB/s]
# diffusion_pytorch_model.bin:  32% 545M/1.72G [00:06<00:08, 136MB/s]
#
# pytorch_model.bin:  91% 556M/608M [00:06<00:00, 144MB/s]
#
# pytorch_model.bin:  95% 577M/608M [00:06<00:00, 153MB/s]
# diffusion_pytorch_model.bin:  33% 566M/1.72G [00:06<00:08, 137MB/s]
#
# pytorch_model.bin:  98% 598M/608M [00:06<00:00, 155MB/s]
# pytorch_model.bin: 100% 608M/608M [00:07<00:00, 85.9MB/s]
# Fetching 15 files:  27% 4/15 [00:07<00:28,  2.60s/it]
# diffusion_pytorch_model.bin:  35% 608M/1.72G [00:07<00:07, 143MB/s]
# diffusion_pytorch_model.bin:  37% 629M/1.72G [00:07<00:06, 157MB/s]
# diffusion_pytorch_model.bin:  38% 650M/1.72G [00:07<00:06, 168MB/s]
# diffusion_pytorch_model.bin:  39% 671M/1.72G [00:07<00:05, 176MB/s]
# diffusion_pytorch_model.bin:  41% 703M/1.72G [00:07<00:05, 179MB/s]
# diffusion_pytorch_model.bin:  42% 724M/1.72G [00:07<00:05, 179MB/s]
# diffusion_pytorch_model.bin:  43% 744M/1.72G [00:07<00:05, 186MB/s]
# diffusion_pytorch_model.bin:  45% 765M/1.72G [00:07<00:05, 185MB/s]
# diffusion_pytorch_model.bin:  46% 786M/1.72G [00:07<00:05, 181MB/s]
# diffusion_pytorch_model.bin:  47% 807M/1.72G [00:08<00:05, 182MB/s]
# diffusion_pytorch_model.bin:  48% 828M/1.72G [00:08<00:04, 186MB/s]
# diffusion_pytorch_model.bin:  49% 849M/1.72G [00:08<00:04, 187MB/s]
# diffusion_pytorch_model.bin:  51% 870M/1.72G [00:08<00:04, 187MB/s]
# diffusion_pytorch_model.bin:  52% 902M/1.72G [00:08<00:04, 197MB/s]
# diffusion_pytorch_model.bin:  54% 933M/1.72G [00:08<00:03, 217MB/s]
# diffusion_pytorch_model.bin:  56% 965M/1.72G [00:08<00:03, 220MB/s]
# diffusion_pytorch_model.bin:  58% 996M/1.72G [00:08<00:03, 213MB/s]
# diffusion_pytorch_model.bin:  60% 1.03G/1.72G [00:09<00:03, 199MB/s]
# diffusion_pytorch_model.bin:  61% 1.05G/1.72G [00:09<00:03, 198MB/s]
# diffusion_pytorch_model.bin:  62% 1.07G/1.72G [00:09<00:03, 199MB/s]
# diffusion_pytorch_model.bin:  63% 1.09G/1.72G [00:10<00:13, 47.5MB/s]
# diffusion_pytorch_model.bin:  65% 1.11G/1.72G [00:10<00:10, 57.0MB/s]
# diffusion_pytorch_model.bin:  66% 1.13G/1.72G [00:11<00:08, 70.4MB/s]
# diffusion_pytorch_model.bin:  67% 1.15G/1.72G [00:11<00:06, 86.4MB/s]
# diffusion_pytorch_model.bin:  68% 1.17G/1.72G [00:11<00:05, 104MB/s]
# diffusion_pytorch_model.bin:  70% 1.21G/1.72G [00:11<00:03, 133MB/s]
# diffusion_pytorch_model.bin:  72% 1.24G/1.72G [00:11<00:03, 159MB/s]
# diffusion_pytorch_model.bin:  74% 1.27G/1.72G [00:11<00:02, 179MB/s]
# diffusion_pytorch_model.bin:  76% 1.30G/1.72G [00:11<00:02, 193MB/s]
# diffusion_pytorch_model.bin:  77% 1.33G/1.72G [00:11<00:01, 210MB/s]
# diffusion_pytorch_model.bin:  79% 1.36G/1.72G [00:12<00:01, 229MB/s]
# diffusion_pytorch_model.bin:  81% 1.39G/1.72G [00:12<00:01, 238MB/s]
# diffusion_pytorch_model.bin:  83% 1.43G/1.72G [00:12<00:01, 241MB/s]
# diffusion_pytorch_model.bin:  85% 1.46G/1.72G [00:12<00:01, 244MB/s]
# diffusion_pytorch_model.bin:  87% 1.49G/1.72G [00:12<00:00, 234MB/s]
# diffusion_pytorch_model.bin:  88% 1.52G/1.72G [00:12<00:00, 229MB/s]
# diffusion_pytorch_model.bin:  90% 1.55G/1.72G [00:12<00:00, 219MB/s]
# diffusion_pytorch_model.bin:  92% 1.58G/1.72G [00:12<00:00, 224MB/s]
# diffusion_pytorch_model.bin:  94% 1.61G/1.72G [00:13<00:00, 224MB/s]
# diffusion_pytorch_model.bin:  96% 1.65G/1.72G [00:13<00:00, 226MB/s]
# diffusion_pytorch_model.bin:  98% 1.68G/1.72G [00:13<00:00, 233MB/s]
# diffusion_pytorch_model.bin: 100% 1.72G/1.72G [00:13<00:00, 127MB/s]
# Fetching 15 files: 100% 15/15 [00:14<00:00,  1.04it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/15/2024 20:46:53 - INFO - __main__ - Number of class images to sample: 120.
# Generating class images: 100% 30/30 [06:18<00:00, 12.62s/it]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:203: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# scheduler/scheduler_config.json: 100% 308/308 [00:00<00:00, 1.40MB/s]
# Caching latents: 100% 120/120 [00:24<00:00,  4.83it/s]
# 04/15/2024 20:53:47 - INFO - __main__ - ***** Running training *****
# 04/15/2024 20:53:47 - INFO - __main__ -   Num examples = 120
# 04/15/2024 20:53:47 - INFO - __main__ -   Num batches each epoch = 120
# 04/15/2024 20:53:47 - INFO - __main__ -   Num Epochs = 7
# 04/15/2024 20:53:47 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/15/2024 20:53:47 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/15/2024 20:53:47 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/15/2024 20:53:47 - INFO - __main__ -   Total optimization steps = 800
# Steps: 100% 800/800 [10:24<00:00,  1.30it/s, loss=0.279, lr=1e-6]safety_checker/model.safetensors not found
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:05<00:15,  5.28s/it]
# Generating samples:  50% 2/4 [00:08<00:08,  4.27s/it]
# Generating samples:  75% 3/4 [00:12<00:03,  3.95s/it]
# Generating samples: 100% 4/4 [00:16<00:00,  4.01s/it]
# [*] Weights saved at /content/stable_diffusion_weights/zwx/800
# Steps: 100% 800/800 [11:07<00:00,  1.20it/s, loss=0.279, lr=1e-6]

# %%
from natsort import natsorted
from glob import glob
import os

weights_dir = natsorted(glob(output_dir + os.sep + '*'))[-1]
print('Weights directory: ', weights_dir)
# Out:
# Weights directory:  /content/stable_diffusion_weights/zwx/800

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

def grid_img(imgs, rows=1, cols=3, scale=1):
  assert len(imgs) == rows * cols

  w, h = imgs[0].size
  w, h = int(w*scale), int(h*scale)

  grid = Image.new('RGB', size=(cols*w, rows*h))
  grid_w, grid_h = grid.size

  for i, img in enumerate(imgs):
      img = img.resize((w,h), Image.ANTIALIAS)
      grid.paste(img, box=(i%cols*w, i//cols*h))
  return grid

# %%
weights_folder = output_dir
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key = lambda x: int(x))

imgs_test = []

for imgs, folder in enumerate(folders):
  folder_path = os.path.join(weights_folder, folder)
  image_folder = os.path.join(folder_path, "samples")
  images = [f for f in os.listdir(image_folder)]

  for i in images:
    img_path = os.path.join(image_folder, i)
    r = Image.open(img_path)
    imgs_test.append(r)

grid_img(imgs_test, rows=1, cols=4, scale=1)
# Out:
# <ipython-input-11-61ea6e59baf2>:15: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((w,h), Image.ANTIALIAS)
# <PIL.Image.Image image mode=RGB size=2048x512>

# %% [markdown]
# ## Convert the weights into (checkpoint)

# %%
ckpt_path = weights_dir + "/model.ckpt"

half_arg = "--half" # fp16

# !python convert_diffusers_to_original_stable_diffusion.py --model_path $weights_dir  --checkpoint_path $ckpt_path $half_arg
print(f"Converted to ckpt and saved in {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# Converted to ckpt and saved in /content/stable_diffusion_weights/zwx/800/model.ckpt

# %% [markdown]
# ## Inference (tests)

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

# %%
model_path = weights_dir
print(model_path)
# Out:
# /content/stable_diffusion_weights/zwx/800

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16).to('cuda')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
seed = 777

# %% [markdown]
# ## Generating images

# %%
prompt = "face portrait of zwx in the snow, realistic, hd, vivid, sunset"
negative_prompt = "bad anatomy, ugly, deformed, desfigured, distorted face, poorly drawn hands, poorly drawn face, poorly drawn feet, blurry, low quality, low definition, lowres, out of frame, out of image, cropped, cut off, signature, watermark"
num_samples = 5
guidance_scale = 7.5
num_inference_steps = 30
height = 512
width = 512

seed = random.randint(0, 2147483647)
print("Seed: {}".format(str(seed)))
generator = torch.Generator(device='cuda').manual_seed(seed)

with autocast("cuda"), torch.inference_mode():
    imgs = pipe(
        prompt,
        negative_prompt=negative_prompt,
        height=height, width=width,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=generator
    ).images

for img in imgs:
    display(img)
# Out:
# Seed: 789346971
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### Testing multiple prompts

# %%
prompt = ["photo of zwx person, closeup, mountain fuji in the background, natural lighting",
          "photo of zwx person in the desert, closeup, pyramids in the background, natural lighting, frontal face",
          "photo of zwx person in the forest, natural lighting, frontal face",
          "photo of zwx person as an astronaut, natural lighting, frontal face, closeup, starry sky in the background",
          "face portrait of zwx in the snow, realistic, hd, vivid, sunset"]

negative_prompt = ["bad anatomy, ugly, deformed, desfigured, distorted face, poorly drawn hands, poorly drawn face, poorly drawn feet, blurry, low quality, low definition, lowres, out of frame, out of image, cropped, cut off, signature, watermark" ] * len(prompt)
num_samples = 1
guidance_scale = 7.5
num_inference_steps = 30
height = 512
width = 512

seed = random.randint(0, 2147483647) # random value
print("Seed: {}".format(str(seed)))
generator = torch.Generator(device='cuda').manual_seed(seed)

with autocast("cuda"), torch.inference_mode():
    imgs = pipe(
        prompt,
        negative_prompt=negative_prompt,
        height=height, width=width,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=generator
    ).images

for img in imgs:
    display(img)
# Out:
# Seed: 1346828236
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6507B73D30>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6507B726E0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6507B73760>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6507B72500>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6507B73C10>

# %% [markdown]
# ### More prompt examples
#
# * in the forest, in cairo, in cairo desert,  in a western scene, in star wars, in mountain fuji, in the snow, etc.
#
# > Other combinations:
#
# * `photo of zwx person, closeup, mountain fuji in the background, natural lighting `
#
# * `digital painting of zwx in the snow, realistic, hd, vivid, sunset`
#
# * `watercolor painting of zwx person, realistic, blue and orange tones `
#
# * `digital painting of zwx person, hyperrealistic, fantasy, Surrealist, painted by Alphonse Mucha`
#
# * `painting of zwx person in star wars, realistic, 4k ultra hd, blue and red tones`
#
# * `photo of zwx person, in an armor, realistic, visible face, colored, detailed face, ultra detailed, natural lighting`
#
# * `photo of zwx person, cyberpunk, vivid, realistic, 4k ultra hd`
#
# * `anime painting of zwx person, chill day, by tim okamura, noah bradley, trending on artstation  `

# %% [markdown]
# ## Saving the results

# %%
# !mkdir results

# %%
for i, img in enumerate(imgs):
  img.save('results/result_{}.png'.format(i+1))

# %% [markdown]
# > More information about this Dreambooth implementation:
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth
